# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../src')))
from matplotlib import pyplot as plt
from src.features.technical_indicators import FeatureTechnicalIndicators
from src.features.feature_selection import plot_feature_importance, select_features
from src.features.ml_features import add_hmm_features, add_rolling_kmeans_cluster_feature, add_nlp_sentiment_score

# %%
# Load sample data
df = pd.read_csv('../datasets/btc_data_with_target.csv', parse_dates=['datetime'], index_col='datetime')

df = add_nlp_sentiment_score(
    df,
    sentiment_file_path='../datasets/bitcoin_sentiments_21_24.csv',
    datetime_col='datetime'
)
# positive: sentiment score > 0
# neutral: sentiment score = 0
# negative: sentiment score < 0
df['sentiment'] = df['sentiment'].apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))

# Display data info
df.head()
# Out:
#                         start_time    difficulty  \
# datetime
# 2020-03-13 02:00:00  1584064800000  1.655292e+13
# 2020-03-13 03:00:00  1584068400000  1.655292e+13
# 2020-03-13 04:00:00  1584072000000  1.655292e+13
# 2020-03-13 05:00:00  1584075600000  1.655292e+13
# 2020-03-13 06:00:00  1584079200000  1.655292e+13
#
#                      start_time_estimated_leverage_ratio  \
# datetime
# 2020-03-13 02:00:00                        1584064800000
# 2020-03-13 03:00:00                        1584068400000
# 2020-03-13 04:00:00                        1584072000000
# 2020-03-13 05:00:00                        1584075600000
# 2020-03-13 06:00:00                        1584079200000
#
#                      estimated_leverage_ratio  start_time_addresses_count  \
# datetime
# 2020-03-13 02:00:00                  0.054695               1584064800000
# 2020-03-13 03:00:00                  0.054014               1584068400000
# 2020-03-13 04:00:00                  0.055290               1584072000000
# 2020-03-13 05:00:00                  0.057333               1584075600000
# 2020-03-13 06:00:00                  0.060129               1584079200000
#
#                      addresses_count_active  addresses_count_receiver  \
# datetime
# 2020-03-13 02:00:00                   48038                     26544
# 2020-03-13 03:00:00                   18207                     12110
# 2020-03-13 04:00:00                   54478                     37906
# 2020-03-13 05:00:00                   55117                     34953
# 2020-03-13 06:00:00                   31961                     18160
#
#                      addresses_count_sender  start_time_exchange_whale_ratio  \
# datetime
# 2020-03-13 02:00:00                   26511                    1584064800000
# 2020-03-13 03:00:00                    7846                    1584068400000
# 2020-03-13 04:00:00                   23715                    1584072000000
# 2020-03-13 05:00:00                   27065                    1584075600000
# 2020-03-13 06:00:00                   18053                    1584079200000
#
#                      exchange_whale_ratio  ...        close         high  \
# datetime                                   ...
# 2020-03-13 02:00:00              0.445868  ...  5003.956097  5539.122307
# 2020-03-13 03:00:00              0.701372  ...  5321.391317  5673.675553
# 2020-03-13 04:00:00              0.396210  ...  4851.922211  5336.407163
# 2020-03-13 05:00:00              0.464358  ...  4996.738882  5266.074097
# 2020-03-13 06:00:00              0.660860  ...  5238.567725  5270.315869
#
#                              low         open         volume  \
# datetime
# 2020-03-13 02:00:00  3878.016146  4200.083158  166560.592230
# 2020-03-13 03:00:00  4963.723548  5002.358452   96918.928217
# 2020-03-13 04:00:00  4716.028720  5308.371877   57978.769349
# 2020-03-13 05:00:00  4782.562902  4793.363609   62983.375418
# 2020-03-13 06:00:00  4876.518529  4996.574164   46180.527435
#
#                      start_time_open_interest  open_interest  future_return  \
# datetime
# 2020-03-13 02:00:00             1584064800000   7.575695e+07       0.063437
# 2020-03-13 03:00:00             1584068400000   7.935403e+07      -0.088223
# 2020-03-13 04:00:00             1584072000000   7.342217e+07       0.029847
# 2020-03-13 05:00:00             1584075600000   7.863121e+07       0.048397
# 2020-03-13 06:00:00             1584079200000   8.624586e+07       0.031998
#
#                      target  sentiment
# datetime
# 2020-03-13 02:00:00       2          0
# 2020-03-13 03:00:00       0          0
# 2020-03-13 04:00:00       2          0
# 2020-03-13 05:00:00       2          0
# 2020-03-13 06:00:00       2          0
#
# [5 rows x 59 columns]

# %%
# 2. Basic technical indicators
print("\n2. Adding basic technical indicators...")
new_df = df.copy()
feature_technical = FeatureTechnicalIndicators(new_df, price_col='close')

# Add individual technical indicators
# feature_technical.add_ema([5, 8, 13])
# feature_technical.add_sma([50, 200])
# feature_technical.add_rsi([14])
# feature_technical.add_macd(fast_window=12, slow_window=26, signal_window=9)
# feature_technical.add_price_change([1])
# feature_technical.add_bollinger_bands([20], num_std=2)

# Add all features at once
feature_technical.add_all_features()

# Show added features by comparing with original DataFrame
added_features = list(set(new_df.columns) - set(df.columns))
print(f"Added {len(added_features)} features: {', '.join(added_features)}")
new_df = new_df.dropna()
new_df.head()
# Out:
# 2. Adding basic technical indicators...
# Added 17 features: macd_trade_signal, price_change_1, ema_13, rsi_14, obv, ema_5_8_13_cross, sma_50, macd_signal_flag, volatility_72, ema_5, bb_signal_20, rsi_obv_signal_14, sma_200, ema_8, volatility_24, volatility_168, macd
#                         start_time    difficulty  \
# datetime
# 2020-03-21 10:00:00  1584784800000  1.655292e+13
# 2020-03-21 11:00:00  1584788400000  1.655292e+13
# 2020-03-21 12:00:00  1584792000000  1.655292e+13
# 2020-03-21 13:00:00  1584795600000  1.655292e+13
# 2020-03-21 14:00:00  1584799200000  1.655292e+13
#
#                      start_time_estimated_leverage_ratio  \
# datetime
# 2020-03-21 10:00:00                        1584784800000
# 2020-03-21 11:00:00                        1584788400000
# 2020-03-21 12:00:00                        1584792000000
# 2020-03-21 13:00:00                        1584795600000
# 2020-03-21 14:00:00                        1584799200000
#
#                      estimated_leverage_ratio  start_time_addresses_count  \
# datetime
# 2020-03-21 10:00:00                  0.068386               1584784800000
# 2020-03-21 11:00:00                  0.070733               1584788400000
# 2020-03-21 12:00:00                  0.069669               1584792000000
# 2020-03-21 13:00:00                  0.069200               1584795600000
# 2020-03-21 14:00:00                  0.069563               1584799200000
#
#                      addresses_count_active  addresses_count_receiver  \
# datetime
# 2020-03-21 10:00:00                   53529                     35483
# 2020-03-21 11:00:00                   28680                     18089
# 2020-03-21 12:00:00                   52721                     32524
# 2020-03-21 13:00:00                   34129                     22669
# 2020-03-21 14:00:00                   35403                     21607
#
#                      addresses_count_sender  start_time_exchange_whale_ratio  \
# datetime
# 2020-03-21 10:00:00                   26362                    1584784800000
# 2020-03-21 11:00:00                   13601                    1584788400000
# 2020-03-21 12:00:00                   27993                    1584792000000
# 2020-03-21 13:00:00                   16683                    1584795600000
# 2020-03-21 14:00:00                   17842                    1584799200000
#
#                      exchange_whale_ratio  ...            obv  \
# datetime                                   ...
# 2020-03-21 10:00:00              0.379854  ...  109271.311496
# 2020-03-21 11:00:00              0.420685  ...  129455.973428
# 2020-03-21 12:00:00              0.736272  ...  149586.905947
# 2020-03-21 13:00:00              0.515419  ...  165797.445016
# 2020-03-21 14:00:00              0.779472  ...  177807.420066
#
#                      rsi_obv_signal_14       macd  macd_signal_flag  \
# datetime
# 2020-03-21 10:00:00                  0 -52.206720                -1
# 2020-03-21 11:00:00                  0 -49.705366                -1
# 2020-03-21 12:00:00                  0 -46.363879                -1
# 2020-03-21 13:00:00                  0 -41.009854                -1
# 2020-03-21 14:00:00                  0 -34.175021                -1
#
#                      macd_trade_signal  price_change_1  volatility_24  \
# datetime
# 2020-03-21 10:00:00                0.0        0.000272       0.018036
# 2020-03-21 11:00:00                0.0        0.024020       0.018587
# 2020-03-21 12:00:00                0.0        0.001668       0.018590
# 2020-03-21 13:00:00                0.0        0.004509       0.018580
# 2020-03-21 14:00:00                0.0        0.004418       0.018456
#
#                      volatility_72  volatility_168  bb_signal_20
# datetime
# 2020-03-21 10:00:00       0.017652        0.022105             0
# 2020-03-21 11:00:00       0.017824        0.022156             0
# 2020-03-21 12:00:00       0.017812        0.022152             0
# 2020-03-21 13:00:00       0.017048        0.022075             0
# 2020-03-21 14:00:00       0.017009        0.022057             0
#
# [5 rows x 76 columns]

# %%
print("\n3. Adding HMM & KMeans cluster features...")

# All the features except target
feature_cols = list(set(new_df.columns) - set(['target']))

# Select features for HMM (Hidden Markov Model)
new_df = add_hmm_features(new_df, feature_cols, n_components=3, n_iter=1000, )

# Add KMeans cluster features using CNN (Rolling KMeans Clustering)
new_df = add_rolling_kmeans_cluster_feature(new_df, feature_cols, n_clusters=3)

new_df
# Out:
# 3. Adding hmm & kmeans features...
#                         start_time    difficulty  \
# datetime
# 2020-03-21 10:00:00  1584784800000  1.655292e+13
# 2020-03-21 11:00:00  1584788400000  1.655292e+13
# 2020-03-21 12:00:00  1584792000000  1.655292e+13
# 2020-03-21 13:00:00  1584795600000  1.655292e+13
# 2020-03-21 14:00:00  1584799200000  1.655292e+13
# ...                            ...           ...
# 2025-03-31 18:00:00  1743444000000  1.137575e+14
# 2025-03-31 19:00:00  1743447600000  1.137575e+14
# 2025-03-31 20:00:00  1743451200000  1.137575e+14
# 2025-03-31 21:00:00  1743454800000  1.137575e+14
# 2025-03-31 22:00:00  1743458400000  1.137575e+14
#
#                      start_time_estimated_leverage_ratio  \
# datetime
# 2020-03-21 10:00:00                        1584784800000
# 2020-03-21 11:00:00                        1584788400000
# 2020-03-21 12:00:00                        1584792000000
# 2020-03-21 13:00:00                        1584795600000
# 2020-03-21 14:00:00                        1584799200000
# ...                                                  ...
# 2025-03-31 18:00:00                        1743444000000
# 2025-03-31 19:00:00                        1743447600000
# 2025-03-31 20:00:00                        1743451200000
# 2025-03-31 21:00:00                        1743454800000
# 2025-03-31 22:00:00                        1743458400000
#
#                      estimated_leverage_ratio  start_time_addresses_count  \
# datetime
# 2020-03-21 10:00:00                  0.068386               1584784800000
# 2020-03-21 11:00:00                  0.070733               1584788400000
# 2020-03-21 12:00:00                  0.069669               1584792000000
# 2020-03-21 13:00:00                  0.069200               1584795600000
# 2020-03-21 14:00:00                  0.069563               1584799200000
# ...                                       ...                         ...
# 2025-03-31 18:00:00                  0.162283               1743444000000
# 2025-03-31 19:00:00                  0.161615               1743447600000
# 2025-03-31 20:00:00                  0.161152               1743451200000
# 2025-03-31 21:00:00                  0.160969               1743454800000
# 2025-03-31 22:00:00                  0.160975               1743458400000
#
#                      addresses_count_active  addresses_count_receiver  \
# datetime
# 2020-03-21 10:00:00                   53529                     35483
# 2020-03-21 11:00:00                   28680                     18089
# 2020-03-21 12:00:00                   52721                     32524
# 2020-03-21 13:00:00                   34129                     22669
# 2020-03-21 14:00:00                   35403                     21607
# ...                                     ...                       ...
# 2025-03-31 18:00:00                   76251                     38448
# 2025-03-31 19:00:00                   59154                     29711
# 2025-03-31 20:00:00                   71194                     36194
# 2025-03-31 21:00:00                   34045                     18446
# 2025-03-31 22:00:00                   53766                     30264
#
#                      addresses_count_sender  start_time_exchange_whale_ratio  \
# datetime
# 2020-03-21 10:00:00                   26362                    1584784800000
# 2020-03-21 11:00:00                   13601                    1584788400000
# 2020-03-21 12:00:00                   27993                    1584792000000
# 2020-03-21 13:00:00                   16683                    1584795600000
# 2020-03-21 14:00:00                   17842                    1584799200000
# ...                                     ...                              ...
# 2025-03-31 18:00:00                   47636                    1743444000000
# 2025-03-31 19:00:00                   36980                    1743447600000
# 2025-03-31 20:00:00                   44509                    1743451200000
# 2025-03-31 21:00:00                   20073                    1743454800000
# 2025-03-31 22:00:00                   31189                    1743458400000
#
#                      exchange_whale_ratio  ...        macd  macd_signal_flag  \
# datetime                                   ...
# 2020-03-21 10:00:00              0.379854  ...  -52.206720                -1
# 2020-03-21 11:00:00              0.420685  ...  -49.705366                -1
# 2020-03-21 12:00:00              0.736272  ...  -46.363879                -1
# 2020-03-21 13:00:00              0.515419  ...  -41.009854                -1
# 2020-03-21 14:00:00              0.779472  ...  -34.175021                -1
# ...                                   ...  ...         ...               ...
# 2025-03-31 18:00:00              0.846697  ...  148.984095                 1
# 2025-03-31 19:00:00              0.997602  ...  110.809464                 1
# 2025-03-31 20:00:00              0.983015  ...   79.409292                 1
# 2025-03-31 21:00:00              0.998356  ...   62.478099                 1
# 2025-03-31 22:00:00              0.999789  ...   35.926190                 1
#
#                      macd_trade_signal  price_change_1  volatility_24  \
# datetime
# 2020-03-21 10:00:00                0.0        0.000272       0.018036
# 2020-03-21 11:00:00                0.0        0.024020       0.018587
# 2020-03-21 12:00:00                0.0        0.001668       0.018590
# 2020-03-21 13:00:00                0.0        0.004509       0.018580
# 2020-03-21 14:00:00                0.0        0.004418       0.018456
# ...                                ...             ...            ...
# 2025-03-31 18:00:00                0.0        0.006807       0.005352
# 2025-03-31 19:00:00                0.0       -0.010128       0.005740
# 2025-03-31 20:00:00                0.0       -0.000035       0.005739
# 2025-03-31 21:00:00                0.0        0.001304       0.005685
# 2025-03-31 22:00:00                0.0       -0.001910       0.005664
#
#                      volatility_72  volatility_168  bb_signal_20  hmm_state  \
# datetime
# 2020-03-21 10:00:00       0.017652        0.022105             0          1
# 2020-03-21 11:00:00       0.017824        0.022156             0          1
# 2020-03-21 12:00:00       0.017812        0.022152             0          1
# 2020-03-21 13:00:00       0.017048        0.022075             0          1
# 2020-03-21 14:00:00       0.017009        0.022057             0          1
# ...                            ...             ...           ...        ...
# 2025-03-31 18:00:00       0.004055        0.003750             0          2
# 2025-03-31 19:00:00       0.004225        0.003823             0          2
# 2025-03-31 20:00:00       0.004225        0.003809             0          2
# 2025-03-31 21:00:00       0.004215        0.003802             0          2
# 2025-03-31 22:00:00       0.004170        0.003763             0          2
#
#                      kmeans_cluster
# datetime
# 2020-03-21 10:00:00               0
# 2020-03-21 11:00:00               0
# 2020-03-21 12:00:00               0
# 2020-03-21 13:00:00               0
# 2020-03-21 14:00:00               0
# ...                             ...
# 2025-03-31 18:00:00               1
# 2025-03-31 19:00:00               1
# 2025-03-31 20:00:00               1
# 2025-03-31 21:00:00               1
# 2025-03-31 22:00:00               1
#
# [43899 rows x 78 columns]

# %%
# Plot Hidden Markov Model (HMM) regimes
for i in range(3):
    plt.plot(new_df[new_df['hmm_state'] == i].index,
                new_df[new_df['hmm_state'] == i]['close'], 
                '.',
                label=f"Regime {i}")
    plt.legend()
    
plt.title("HMM Regimes")
plt.xlabel("Datetime")
plt.ylabel("Price")   
plt.show()

# Plot KMeans clusters
for i in range(3):
    plt.plot(new_df[new_df['kmeans_cluster'] == i].index,
                new_df[new_df['kmeans_cluster'] == i]['close'], 
                '.',
                label=f"Cluster {i}")
    plt.legend()
    
plt.title("KMeans Cluster")
plt.xlabel("Datetime")
plt.ylabel("Price")   
    
plt.show()

# %%
# 4. Feature selection
### NOTE: the target column should be the one you want to predict, i.e., 'buy' or 'sell' signal
print("\n4. Feature selection...") 
new_df2 = new_df.copy()

target_col = 'target'
X = new_df2.drop(columns=[target_col])
top10_all = plot_feature_importance(new_df2, target_col=target_col, feature_cols=list(X.columns), top_n=20, save_img_path='feature_importance_all.png', method='correlation')
print(f"Top 20 features (all): {top10_all}")

# Select features based on correlation
new_df2 = select_features(new_df2, features=top10_all + ['close'])
new_df2
# Out:
# 4. Feature selection...
#
# Top Features:
#                              feature  importance
#                        future_return    0.657089
#                       price_change_1    0.072646
#                     ema_5_8_13_cross    0.059364
#                     taker_sell_ratio    0.056887
#                      taker_buy_ratio    0.056887
#                 taker_buy_sell_ratio    0.056255
#                               rsi_14    0.052857
#                    rsi_obv_signal_14    0.052490
#                         bb_signal_20    0.048031
# coinbase_premium_index_usdt_adjusted    0.044686
#                     macd_signal_flag    0.042455
#   coinbase_premium_gap_usdt_adjusted    0.034411
#                    macd_trade_signal    0.030390
#                                 macd    0.022632
#               addresses_count_sender    0.017216
#               addresses_count_active    0.017068
#                          blockreward    0.015843
#              tokens_transferred_mean    0.013464
#                    long_liquidations    0.013461
#             addresses_count_receiver    0.012959
#
# Plot saved to: feature_importance_all.png
# Top 20 features (all): ['future_return', 'price_change_1', 'ema_5_8_13_cross', 'taker_sell_ratio', 'taker_buy_ratio', 'taker_buy_sell_ratio', 'rsi_14', 'rsi_obv_signal_14', 'bb_signal_20', 'coinbase_premium_index_usdt_adjusted', 'macd_signal_flag', 'coinbase_premium_gap_usdt_adjusted', 'macd_trade_signal', 'macd', 'addresses_count_sender', 'addresses_count_active', 'blockreward', 'tokens_transferred_mean', 'long_liquidations', 'addresses_count_receiver']
#                      future_return  price_change_1  ema_5_8_13_cross  \
# datetime
# 2020-03-21 10:00:00       0.024020        0.000272                -1
# 2020-03-21 11:00:00       0.001668        0.024020                -1
# 2020-03-21 12:00:00       0.004509        0.001668                -1
# 2020-03-21 13:00:00       0.004418        0.004509                -1
# 2020-03-21 14:00:00       0.003962        0.004418                 0
# ...                            ...             ...               ...
# 2025-03-31 18:00:00      -0.010128        0.006807                 1
# 2025-03-31 19:00:00      -0.000035       -0.010128                 1
# 2025-03-31 20:00:00       0.001304       -0.000035                 0
# 2025-03-31 21:00:00      -0.001910        0.001304                 0
# 2025-03-31 22:00:00       0.001746       -0.001910                 0
#
#                      taker_sell_ratio  taker_buy_ratio  taker_buy_sell_ratio  \
# datetime
# 2020-03-21 10:00:00          0.431148         0.568852              1.319389
# 2020-03-21 11:00:00          0.439940         0.560060              1.273038
# 2020-03-21 12:00:00          0.455694         0.544306              1.194454
# 2020-03-21 13:00:00          0.460852         0.539148              1.169896
# 2020-03-21 14:00:00          0.469738         0.530262              1.128848
# ...                               ...              ...                   ...
# 2025-03-31 18:00:00          0.488277         0.511723              1.048020
# 2025-03-31 19:00:00          0.531443         0.468557              0.881669
# 2025-03-31 20:00:00          0.469972         0.530028              1.127787
# 2025-03-31 21:00:00          0.438441         0.561559              1.280809
# 2025-03-31 22:00:00          0.496519         0.503481              1.014021
#
#                         rsi_14  rsi_obv_signal_14  bb_signal_20  \
# datetime
# 2020-03-21 10:00:00  50.425143                  0             0
# 2020-03-21 11:00:00  44.655167                  0             0
# 2020-03-21 12:00:00  48.718366                  0             0
# 2020-03-21 13:00:00  47.935088                  0             0
# 2020-03-21 14:00:00  52.854334                  0             0
# ...                        ...                ...           ...
# 2025-03-31 18:00:00  63.752812                  0             0
# 2025-03-31 19:00:00  51.857905                  0             0
# 2025-03-31 20:00:00  53.745562                  0             0
# 2025-03-31 21:00:00  55.758062                  0             0
# 2025-03-31 22:00:00  53.521800                  0             0
#
#                      coinbase_premium_index_usdt_adjusted  ...  \
# datetime                                                   ...
# 2020-03-21 10:00:00                             -0.175436  ...
# 2020-03-21 11:00:00                             -0.156036  ...
# 2020-03-21 12:00:00                             -0.014339  ...
# 2020-03-21 13:00:00                             -0.064420  ...
# 2020-03-21 14:00:00                             -0.176263  ...
# ...                                                   ...  ...
# 2025-03-31 18:00:00                             -0.006184  ...
# 2025-03-31 19:00:00                             -0.004337  ...
# 2025-03-31 20:00:00                             -0.000067  ...
# 2025-03-31 21:00:00                             -0.000623  ...
# 2025-03-31 22:00:00                             -0.009237  ...
#
#                      coinbase_premium_gap_usdt_adjusted  macd_trade_signal  \
# datetime
# 2020-03-21 10:00:00                          -10.461607                0.0
# 2020-03-21 11:00:00                           -9.534288                0.0
# 2020-03-21 12:00:00                           -0.877953                0.0
# 2020-03-21 13:00:00                           -3.965553                0.0
# 2020-03-21 14:00:00                          -10.877320                0.0
# ...                                                 ...                ...
# 2025-03-31 18:00:00                           -5.150837                0.0
# 2025-03-31 19:00:00                           -3.576791                0.0
# 2025-03-31 20:00:00                           -0.055302                0.0
# 2025-03-31 21:00:00                           -0.514716                0.0
# 2025-03-31 22:00:00                           -7.613570                0.0
#
#                            macd  addresses_count_sender  \
# datetime
# 2020-03-21 10:00:00  -52.206720                   26362
# 2020-03-21 11:00:00  -49.705366                   13601
# 2020-03-21 12:00:00  -46.363879                   27993
# 2020-03-21 13:00:00  -41.009854                   16683
# 2020-03-21 14:00:00  -34.175021                   17842
# ...                         ...                     ...
# 2025-03-31 18:00:00  148.984095                   47636
# 2025-03-31 19:00:00  110.809464                   36980
# 2025-03-31 20:00:00   79.409292                   44509
# 2025-03-31 21:00:00   62.478099                   20073
# 2025-03-31 22:00:00   35.926190                   31189
#
#                      addresses_count_active  blockreward  \
# datetime
# 2020-03-21 10:00:00                   53529    79.425701
# 2020-03-21 11:00:00                   28680    38.953772
# 2020-03-21 12:00:00                   52721    89.747683
# 2020-03-21 13:00:00                   34129    77.994278
# 2020-03-21 14:00:00                   35403    52.579252
# ...                                     ...          ...
# 2025-03-31 18:00:00                   76251    22.152889
# 2025-03-31 19:00:00                   59154    19.119721
# 2025-03-31 20:00:00                   71194    31.509539
# 2025-03-31 21:00:00                   34045    28.228245
# 2025-03-31 22:00:00                   53766    15.776004
#
#                      tokens_transferred_mean  long_liquidations  \
# datetime
# 2020-03-21 10:00:00                 4.404927          26.845000
# 2020-03-21 11:00:00                 2.575115         175.261000
# 2020-03-21 12:00:00                 2.304383          19.862000
# 2020-03-21 13:00:00                 2.467700          53.855000
# 2020-03-21 14:00:00                 6.132433          53.725000
# ...                                      ...                ...
# 2025-03-31 18:00:00                 1.676118           0.097000
# 2025-03-31 19:00:00                 1.976558           7.523869
# 2025-03-31 20:00:00                 3.400298           0.464244
# 2025-03-31 21:00:00                 1.899223           0.197000
# 2025-03-31 22:00:00                 1.231501           1.185439
#
#                      addresses_count_receiver         close
# datetime
# 2020-03-21 10:00:00                     35483   5983.856451
# 2020-03-21 11:00:00                     18089   6127.590660
# 2020-03-21 12:00:00                     32524   6137.810955
# 2020-03-21 13:00:00                     22669   6165.485900
# 2020-03-21 14:00:00                     21607   6192.722682
# ...                                       ...           ...
# 2025-03-31 18:00:00                     38448  83287.446732
# 2025-03-31 19:00:00                     29711  82443.899978
# 2025-03-31 20:00:00                     36194  82441.035723
# 2025-03-31 21:00:00                     18446  82548.529858
# 2025-03-31 22:00:00                     30264  82390.896662
#
# [43899 rows x 21 columns]

# %%
# Show column close, sentiment, target
new_df[['close', 'sentiment', 'target']].head(10)

# Count unique values in sentiment
print(new_df['sentiment'].value_counts())
# Out:
# sentiment
#  0    38940
#  1     3011
# -1     1948
# Name: count, dtype: int64

# %%
# Save the new DataFrame to a CSV file
new_df.to_csv('../datasets/btc_data_with_target_technical_hmm_kmeans.csv', index=True)
